# %%
# Out:
# '/content'

# %%
# !git clone https://github.com/JaidedAI/EasyOCR.git
# Out:
# Cloning into 'EasyOCR'...
# remote: Enumerating objects: 2750, done.
# remote: Total 2750 (delta 0), reused 0 (delta 0), pack-reused 2750 (from 1)
# Receiving objects: 100% (2750/2750), 157.84 MiB | 23.53 MiB/s, done.
# Resolving deltas: 100% (1672/1672), done.
# Updating files: 100% (313/313), done.

# %%
import os
os.chdir("/content/EasyOCR/trainer/craft")
os.getcwd()
# Out:
# '/content/EasyOCR/trainer/craft'

# %%
# !unzip "/content/EasyOCR/trainer/craft/data_root_dir/ch4_training_localization_transcription_gt.zip" -d "/content/EasyOCR/trainer/craft/data_root_dir/ch4_training_localization_transcription_gt/"
# Out:
# Archive:  /content/EasyOCR/trainer/craft/data_root_dir/ch4_training_localization_transcription_gt.zip
#   inflating: /content/EasyOCR/trainer/craft/data_root_dir/ch4_training_localization_transcription_gt/gt_img_1.txt
#   inflating: /content/EasyOCR/trainer/craft/data_root_dir/ch4_training_localization_transcription_gt/gt_img_2.txt
#   inflating: /content/EasyOCR/trainer/craft/data_root_dir/ch4_training_localization_transcription_gt/gt_img_3.txt
#   inflating: /content/EasyOCR/trainer/craft/data_root_dir/ch4_training_localization_transcription_gt/gt_img_4.txt
#   inflating: /content/EasyOCR/trainer/craft/data_root_dir/ch4_training_localization_transcription_gt/gt_img_5.txt
#   inflating: /content/EasyOCR/trainer/craft/data_root_dir/ch4_training_localization_transcription_gt/gt_img_6.txt
#   inflating: /content/EasyOCR/trainer/craft/data_root_dir/ch4_training_localization_transcription_gt/gt_img_7.txt
# ...

# %%
# !python train.py --yaml custom_data_train
# Out:
# -------------------- Options --------------------
# data_root_dir: ./data_root_dir/
# mode: weak_supervision
# results_dir: ./exp/
# score_gt_dir: None
# test:
#   custom_data:
#     canvas_size: 2240
#     cuda: true
#     link_threshold: 0.2
#     low_text: 0.5
#     mag_ratio: 1.75
#     poly: false
#     test_data_dir: ./data_root_dir/
#     test_set_size: 500
#     text_threshold: 0.75
#     vis_opt: false
#   trained_model: null
# train:
#   amp: true
#   backbone: vgg
#   batch_size: 5
#   ckpt_path: ./pretrained_model/CRAFT_clr_amp_29500.pth
#   data:
#     custom_aug:
#       random_colorjitter:
#         brightness: 0.2
#         contrast: 0.2
#         hue: 0.2
#         option: true
#         saturation: 0.2
#       random_crop:
#         option: true
#         ratio:
#         - 0.75
#         - 1.33
#         rnd_threshold: 1.0
#         scale:
#         - 0.03
#         - 0.4
#         version: random_resize_crop
#       random_horizontal_flip:
#         option: true
# ...

# %%
# !unzip "/content/EasyOCR/trainer/craft/data_root_dir/ch4_test_images.zip" -d "/content/EasyOCR/trainer/craft/data_root_dir/ch4_test_images/"
# Out:
# Archive:  /content/EasyOCR/trainer/craft/data_root_dir/ch4_test_images.zip
#   inflating: /content/EasyOCR/trainer/craft/data_root_dir/ch4_test_images/img_1.jpg
#   inflating: /content/EasyOCR/trainer/craft/data_root_dir/ch4_test_images/img_2.jpg
#   inflating: /content/EasyOCR/trainer/craft/data_root_dir/ch4_test_images/img_3.jpg
#   inflating: /content/EasyOCR/trainer/craft/data_root_dir/ch4_test_images/img_4.jpg
#   inflating: /content/EasyOCR/trainer/craft/data_root_dir/ch4_test_images/img_5.jpg
#   inflating: /content/EasyOCR/trainer/craft/data_root_dir/ch4_test_images/img_6.jpg
#   inflating: /content/EasyOCR/trainer/craft/data_root_dir/ch4_test_images/img_7.jpg
#   inflating: /content/EasyOCR/trainer/craft/data_root_dir/ch4_test_images/img_8.jpg
#   inflating: /content/EasyOCR/trainer/craft/data_root_dir/ch4_test_images/img_9.jpg
#   inflating: /content/EasyOCR/trainer/craft/data_root_dir/ch4_test_images/img_10.jpg
# ...

# %%
# !unzip "/content/EasyOCR/trainer/craft/data_root_dir/ch4_training_images.zip" -d "/content/EasyOCR/trainer/craft/data_root_dir/ch4_training_images/"
# Out:
# Archive:  /content/EasyOCR/trainer/craft/data_root_dir/ch4_training_images.zip
#   inflating: /content/EasyOCR/trainer/craft/data_root_dir/ch4_training_images/img_1.jpg
#   inflating: /content/EasyOCR/trainer/craft/data_root_dir/ch4_training_images/img_2.jpg
#   inflating: /content/EasyOCR/trainer/craft/data_root_dir/ch4_training_images/img_3.jpg
#   inflating: /content/EasyOCR/trainer/craft/data_root_dir/ch4_training_images/img_4.jpg
#   inflating: /content/EasyOCR/trainer/craft/data_root_dir/ch4_training_images/img_5.jpg
#   inflating: /content/EasyOCR/trainer/craft/data_root_dir/ch4_training_images/img_6.jpg
#   inflating: /content/EasyOCR/trainer/craft/data_root_dir/ch4_training_images/img_7.jpg
#   inflating: /content/EasyOCR/trainer/craft/data_root_dir/ch4_training_images/img_8.jpg
#   inflating: /content/EasyOCR/trainer/craft/data_root_dir/ch4_training_images/img_9.jpg
#   inflating: /content/EasyOCR/trainer/craft/data_root_dir/ch4_training_images/img_10.jpg
# ...

# %%
# !python train.py --yaml custom_data_train
# Out:
# -------------------- Options --------------------
# data_root_dir: ./data_root_dir/
# mode: weak_supervision
# results_dir: ./exp/
# score_gt_dir: None
# test:
#   custom_data:
#     canvas_size: 2240
#     cuda: true
#     link_threshold: 0.2
#     low_text: 0.5
#     mag_ratio: 1.75
#     poly: false
#     test_data_dir: ./data_root_dir/
#     test_set_size: 500
#     text_threshold: 0.75
#     vis_opt: false
#   trained_model: null
# train:
#   amp: true
#   backbone: vgg
#   batch_size: 5
#   ckpt_path: ./pretrained_model/CRAFT_clr_amp_29500.pth
#   data:
#     custom_aug:
#       random_colorjitter:
#         brightness: 0.2
#         contrast: 0.2
#         hue: 0.2
#         option: true
#         saturation: 0.2
#       random_crop:
#         option: true
#         ratio:
#         - 0.75
#         - 1.33
#         rnd_threshold: 1.0
#         scale:
#         - 0.03
#         - 0.4
#         version: random_resize_crop
#       random_horizontal_flip:
#         option: true
# ...
